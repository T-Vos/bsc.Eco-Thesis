# %%
from moralis import Moralis 
Moralis(blocks=500, block_start=13296676,data_folder="../data/Moralis/")
# Out:
# trying to get block 1from blockchain 13296676
# trying to get block 1from blockchain 13296677
# trying to get block 1from blockchain 13296678
# trying to get block 1from blockchain 13296679
# trying to get block 1from blockchain 13296680
# trying to get block 1from blockchain 13296681
# trying to get block 1from blockchain 13296682
# trying to get block 1from blockchain 13296683
# trying to get block 1from blockchain 13296684
# trying to get block 1from blockchain 13296685
# trying to get block 1from blockchain 13296686
# trying to get block 1from blockchain 13296687
# trying to get block 1from blockchain 13296688
# trying to get block 1from blockchain 13296689
# trying to get block 1from blockchain 13296690
# trying to get block 1from blockchain 13296691
# trying to get block 1from blockchain 13296692
# trying to get block 1from blockchain 13296693
# trying to get block 1from blockchain 13296694
# trying to get block 1from blockchain 13296695
# trying to get block 1from blockchain 13296696
# trying to get block 1from blockchain 13296697
# trying to get block 1from blockchain 13296698
# trying to get block 1from blockchain 13296699
# trying to get block 1from blockchain 13296700
# trying to get block 1from blockchain 13296701
# trying to get block 1from blockchain 13296702
# trying to get block 1from blockchain 13296703
# trying to get block 1from blockchain 13296704
# trying to get block 1from blockchain 13296705
# trying to get block 1from blockchain 13296706
# trying to get block 1from blockchain 13296707
# trying to get block 1from blockchain 13296708
# trying to get block 1from blockchain 13296709
# trying to get block 1from blockchain 13296710
# trying to get block 1from blockchain 13296711
# trying to get block 1from blockchain 13296712
# trying to get block 1from blockchain 13296713
# trying to get block 1from blockchain 13296714
# trying to get block 1from blockchain 13296715
# trying to get block 1from blockchain 13296716
# trying to get block 1from blockchain 13296717
# trying to get block 1from blockchain 13296718
# trying to get block 1from blockchain 13296719
# trying to get block 1from blockchain 13296720
# trying to get block 1from blockchain 13296721
# trying to get block 1from blockchain 13296722
# trying to get block 1from blockchain 13296723
# trying to get block 1from blockchain 13296724
# trying to get block 1from blockchain 13296725
# trying to get block 1from blockchain 13296726
# trying to get block 1from blockchain 13296727
# trying to get block 1from blockchain 13296728
# trying to get block 1from blockchain 13296729
# trying to get block 1from blockchain 13296730
# trying to get block 1from blockchain 13296731
# trying to get block 1from blockchain 13296732
# trying to get block 1from blockchain 13296733
# trying to get block 1from blockchain 13296734
# trying to get block 1from blockchain 13296735
# trying to get block 1from blockchain 13296736
# trying to get block 1from blockchain 13296737
# trying to get block 1from blockchain 13296738
# trying to get block 1from blockchain 13296739
# trying to get block 1from blockchain 13296740
# trying to get block 1from blockchain 13296741
# trying to get block 1from blockchain 13296742
# trying to get block 1from blockchain 13296743
# trying to get block 1from blockchain 13296744
# trying to get block 1from blockchain 13296745
# trying to get block 1from blockchain 13296746
# trying to get block 1from blockchain 13296747
# trying to get block 1from blockchain 13296748
# trying to get block 1from blockchain 13296749
# trying to get block 1from blockchain 13296750
# trying to get block 1from blockchain 13296751
# trying to get block 1from blockchain 13296752
# trying to get block 1from blockchain 13296753
# trying to get block 1from blockchain 13296754
# trying to get block 1from blockchain 13296755
# trying to get block 1from blockchain 13296756
# trying to get block 1from blockchain 13296757
# trying to get block 1from blockchain 13296758
# trying to get block 1from blockchain 13296759
# trying to get block 1from blockchain 13296760
# trying to get block 1from blockchain 13296761
# trying to get block 1from blockchain 13296762
# trying to get block 1from blockchain 13296763
# trying to get block 1from blockchain 13296764
# trying to get block 1from blockchain 13296765
# trying to get block 1from blockchain 13296766
# trying to get block 1from blockchain 13296767
# trying to get block 1from blockchain 13296768
# trying to get block 1from blockchain 13296769
# trying to get block 1from blockchain 13296770
# trying to get block 1from blockchain 13296771
# trying to get block 1from blockchain 13296772
# trying to get block 1from blockchain 13296773
# trying to get block 1from blockchain 13296774
# trying to get block 1from blockchain 13296775
# trying to get block 1from blockchain 13296776
# trying to get block 1from blockchain 13296777
# trying to get block 1from blockchain 13296778
# trying to get block 1from blockchain 13296779
# trying to get block 1from blockchain 13296780
# trying to get block 1from blockchain 13296781
# trying to get block 1from blockchain 13296782
# trying to get block 1from blockchain 13296783
# trying to get block 1from blockchain 13296784
# trying to get block 1from blockchain 13296785
# trying to get block 1from blockchain 13296786
# trying to get block 1from blockchain 13296787
# trying to get block 1from blockchain 13296788
# trying to get block 1from blockchain 13296789
# trying to get block 1from blockchain 13296790
# trying to get block 1from blockchain 13296791
# trying to get block 1from blockchain 13296792
# trying to get block 1from blockchain 13296793
# trying to get block 1from blockchain 13296794
# trying to get block 1from blockchain 13296795
# trying to get block 1from blockchain 13296796
# trying to get block 1from blockchain 13296797
# trying to get block 1from blockchain 13296798
# trying to get block 1from blockchain 13296799
# trying to get block 1from blockchain 13296800
# trying to get block 1from blockchain 13296801
# trying to get block 1from blockchain 13296802
# trying to get block 1from blockchain 13296803
# trying to get block 1from blockchain 13296804
# trying to get block 1from blockchain 13296805
# trying to get block 1from blockchain 13296806
# trying to get block 1from blockchain 13296807
# trying to get block 1from blockchain 13296808
# trying to get block 1from blockchain 13296809
# trying to get block 1from blockchain 13296810
# trying to get block 1from blockchain 13296811
# trying to get block 1from blockchain 13296812
# trying to get block 1from blockchain 13296813
# trying to get block 1from blockchain 13296814
# trying to get block 1from blockchain 13296815
# trying to get block 1from blockchain 13296816
# trying to get block 1from blockchain 13296817
# trying to get block 1from blockchain 13296818
# trying to get block 1from blockchain 13296819
# trying to get block 1from blockchain 13296820
# trying to get block 1from blockchain 13296821
# trying to get block 1from blockchain 13296822
# trying to get block 1from blockchain 13296823
# trying to get block 1from blockchain 13296824
# trying to get block 1from blockchain 13296825
# trying to get block 1from blockchain 13296826
# trying to get block 1from blockchain 13296827
# trying to get block 1from blockchain 13296828
# trying to get block 1from blockchain 13296829
# trying to get block 1from blockchain 13296830
# trying to get block 1from blockchain 13296831
# trying to get block 1from blockchain 13296832
# trying to get block 1from blockchain 13296833
# trying to get block 1from blockchain 13296834
# trying to get block 1from blockchain 13296835
# trying to get block 1from blockchain 13296836
# trying to get block 1from blockchain 13296837
# trying to get block 1from blockchain 13296838
# trying to get block 1from blockchain 13296839
# trying to get block 1from blockchain 13296840
# trying to get block 1from blockchain 13296841
# trying to get block 1from blockchain 13296842
# trying to get block 1from blockchain 13296843
# trying to get block 1from blockchain 13296844
# trying to get block 1from blockchain 13296845
# trying to get block 1from blockchain 13296846
# trying to get block 1from blockchain 13296847
# trying to get block 1from blockchain 13296848
# trying to get block 1from blockchain 13296849
# trying to get block 1from blockchain 13296850
# trying to get block 1from blockchain 13296851
# trying to get block 1from blockchain 13296852
# trying to get block 1from blockchain 13296853
# trying to get block 1from blockchain 13296854
# trying to get block 1from blockchain 13296855
# trying to get block 1from blockchain 13296856
# trying to get block 1from blockchain 13296857
# trying to get block 1from blockchain 13296858
# trying to get block 1from blockchain 13296859
# trying to get block 1from blockchain 13296860
# trying to get block 1from blockchain 13296861
# trying to get block 1from blockchain 13296862
# trying to get block 1from blockchain 13296863
# trying to get block 1from blockchain 13296864
# trying to get block 1from blockchain 13296865
# trying to get block 1from blockchain 13296866
# trying to get block 1from blockchain 13296867
# trying to get block 1from blockchain 13296868
# trying to get block 1from blockchain 13296869
# trying to get block 1from blockchain 13296870
# trying to get block 1from blockchain 13296871
# trying to get block 1from blockchain 13296872
# trying to get block 1from blockchain 13296873
# trying to get block 1from blockchain 13296874
# trying to get block 1from blockchain 13296875
# trying to get block 1from blockchain 13296876
# trying to get block 1from blockchain 13296877
# trying to get block 1from blockchain 13296878
# trying to get block 1from blockchain 13296879
# trying to get block 1from blockchain 13296880
# trying to get block 1from blockchain 13296881
# trying to get block 1from blockchain 13296882
# trying to get block 1from blockchain 13296883
# trying to get block 1from blockchain 13296884
# trying to get block 1from blockchain 13296885
# trying to get block 1from blockchain 13296886
# trying to get block 1from blockchain 13296887
# trying to get block 1from blockchain 13296888
# trying to get block 1from blockchain 13296889
# trying to get block 1from blockchain 13296890
# trying to get block 1from blockchain 13296891
# trying to get block 1from blockchain 13296892
# trying to get block 1from blockchain 13296893
# trying to get block 1from blockchain 13296894
# trying to get block 1from blockchain 13296895
# trying to get block 1from blockchain 13296896
# trying to get block 1from blockchain 13296897
# trying to get block 1from blockchain 13296898
# trying to get block 1from blockchain 13296899
# trying to get block 1from blockchain 13296900
# trying to get block 1from blockchain 13296901
# trying to get block 1from blockchain 13296902
# trying to get block 1from blockchain 13296903
# trying to get block 1from blockchain 13296904
# trying to get block 1from blockchain 13296905
# trying to get block 1from blockchain 13296906
# trying to get block 1from blockchain 13296907
# trying to get block 1from blockchain 13296908
# trying to get block 1from blockchain 13296909
# trying to get block 1from blockchain 13296910
# trying to get block 1from blockchain 13296911
# trying to get block 1from blockchain 13296912
# trying to get block 1from blockchain 13296913
# trying to get block 1from blockchain 13296914
# trying to get block 1from blockchain 13296915
# trying to get block 1from blockchain 13296916
# trying to get block 1from blockchain 13296917
# trying to get block 1from blockchain 13296918
# trying to get block 1from blockchain 13296919
# trying to get block 1from blockchain 13296920
# trying to get block 1from blockchain 13296921
# trying to get block 1from blockchain 13296922
# trying to get block 1from blockchain 13296923
# trying to get block 1from blockchain 13296924
# trying to get block 1from blockchain 13296925
# trying to get block 1from blockchain 13296926
# trying to get block 1from blockchain 13296927
# trying to get block 1from blockchain 13296928
# trying to get block 1from blockchain 13296929
# trying to get block 1from blockchain 13296930
# trying to get block 1from blockchain 13296931
# trying to get block 1from blockchain 13296932
# trying to get block 1from blockchain 13296933
# trying to get block 1from blockchain 13296934
# trying to get block 1from blockchain 13296935
# trying to get block 1from blockchain 13296936
# trying to get block 1from blockchain 13296937
# trying to get block 1from blockchain 13296938
# trying to get block 1from blockchain 13296939
# trying to get block 1from blockchain 13296940
# trying to get block 1from blockchain 13296941
# trying to get block 1from blockchain 13296942
# trying to get block 1from blockchain 13296943
# trying to get block 1from blockchain 13296944
# trying to get block 1from blockchain 13296945
# trying to get block 1from blockchain 13296946
# trying to get block 1from blockchain 13296947
# trying to get block 1from blockchain 13296948
# trying to get block 1from blockchain 13296949
# trying to get block 1from blockchain 13296950
# trying to get block 1from blockchain 13296951
# trying to get block 1from blockchain 13296952
# trying to get block 1from blockchain 13296953
# trying to get block 1from blockchain 13296954
# trying to get block 1from blockchain 13296955
# trying to get block 1from blockchain 13296956
# trying to get block 1from blockchain 13296957
# trying to get block 1from blockchain 13296958
# trying to get block 1from blockchain 13296959
# trying to get block 1from blockchain 13296960
# trying to get block 1from blockchain 13296961
# trying to get block 1from blockchain 13296962
# trying to get block 1from blockchain 13296963
# trying to get block 1from blockchain 13296964
# trying to get block 1from blockchain 13296965
# trying to get block 1from blockchain 13296966
# trying to get block 1from blockchain 13296967
# trying to get block 1from blockchain 13296968
# trying to get block 1from blockchain 13296969
# trying to get block 1from blockchain 13296970
# trying to get block 1from blockchain 13296971
# trying to get block 1from blockchain 13296972
# trying to get block 1from blockchain 13296973
# trying to get block 1from blockchain 13296974
# trying to get block 1from blockchain 13296975
# trying to get block 1from blockchain 13296976
# trying to get block 1from blockchain 13296977
# trying to get block 1from blockchain 13296978
# trying to get block 1from blockchain 13296979
# trying to get block 1from blockchain 13296980
# trying to get block 1from blockchain 13296981
# trying to get block 1from blockchain 13296982
# trying to get block 1from blockchain 13296983
# trying to get block 1from blockchain 13296984
# trying to get block 1from blockchain 13296985
# trying to get block 1from blockchain 13296986
# trying to get block 1from blockchain 13296987
# trying to get block 1from blockchain 13296988
# trying to get block 1from blockchain 13296989
# trying to get block 1from blockchain 13296990
# trying to get block 1from blockchain 13296991
# trying to get block 1from blockchain 13296992
# trying to get block 1from blockchain 13296993
# trying to get block 1from blockchain 13296994
# trying to get block 1from blockchain 13296995
# trying to get block 1from blockchain 13296996
# trying to get block 1from blockchain 13296997
# trying to get block 1from blockchain 13296998
# trying to get block 1from blockchain 13296999
# trying to get block 1from blockchain 13297000
# trying to get block 1from blockchain 13297001
# trying to get block 1from blockchain 13297002
# trying to get block 1from blockchain 13297003
# trying to get block 1from blockchain 13297004
# trying to get block 1from blockchain 13297005
# trying to get block 1from blockchain 13297006
# trying to get block 1from blockchain 13297007
# trying to get block 1from blockchain 13297008
# trying to get block 1from blockchain 13297009
# trying to get block 1from blockchain 13297010
# trying to get block 1from blockchain 13297011
# trying to get block 1from blockchain 13297012
# trying to get block 1from blockchain 13297013
# trying to get block 1from blockchain 13297014
# trying to get block 1from blockchain 13297015
# trying to get block 1from blockchain 13297016
# trying to get block 1from blockchain 13297017
# trying to get block 1from blockchain 13297018
# trying to get block 1from blockchain 13297019
# trying to get block 1from blockchain 13297020
# trying to get block 1from blockchain 13297021
# trying to get block 1from blockchain 13297022
# trying to get block 1from blockchain 13297023
# trying to get block 1from blockchain 13297024
# trying to get block 1from blockchain 13297025
# trying to get block 1from blockchain 13297026
# trying to get block 1from blockchain 13297027
# trying to get block 1from blockchain 13297028
# trying to get block 1from blockchain 13297029
# trying to get block 1from blockchain 13297030
# trying to get block 1from blockchain 13297031
# trying to get block 1from blockchain 13297032
# trying to get block 1from blockchain 13297033
# trying to get block 1from blockchain 13297034
# trying to get block 1from blockchain 13297035
# trying to get block 1from blockchain 13297036
# trying to get block 1from blockchain 13297037
# trying to get block 1from blockchain 13297038
# trying to get block 1from blockchain 13297039
# trying to get block 1from blockchain 13297040
# trying to get block 1from blockchain 13297041
# trying to get block 1from blockchain 13297042
# trying to get block 1from blockchain 13297043
# trying to get block 1from blockchain 13297044
# trying to get block 1from blockchain 13297045
# trying to get block 1from blockchain 13297046
# trying to get block 1from blockchain 13297047
# trying to get block 1from blockchain 13297048
# trying to get block 1from blockchain 13297049
# trying to get block 1from blockchain 13297050
# trying to get block 1from blockchain 13297051
# trying to get block 1from blockchain 13297052
# trying to get block 1from blockchain 13297053
# trying to get block 1from blockchain 13297054
# trying to get block 1from blockchain 13297055
# trying to get block 1from blockchain 13297056
# trying to get block 1from blockchain 13297057
# trying to get block 1from blockchain 13297058
# trying to get block 1from blockchain 13297059
# trying to get block 1from blockchain 13297060
# trying to get block 1from blockchain 13297061
# trying to get block 1from blockchain 13297062
# trying to get block 1from blockchain 13297063
# trying to get block 1from blockchain 13297064
# trying to get block 1from blockchain 13297065
# trying to get block 1from blockchain 13297066
# trying to get block 1from blockchain 13297067
# trying to get block 1from blockchain 13297068
# trying to get block 1from blockchain 13297069
# trying to get block 1from blockchain 13297070
# trying to get block 1from blockchain 13297071
# trying to get block 1from blockchain 13297072
# trying to get block 1from blockchain 13297073
# trying to get block 1from blockchain 13297074
# trying to get block 1from blockchain 13297075
# trying to get block 1from blockchain 13297076
# trying to get block 1from blockchain 13297077
# trying to get block 1from blockchain 13297078
# trying to get block 1from blockchain 13297079
# trying to get block 1from blockchain 13297080
# trying to get block 1from blockchain 13297081
# trying to get block 1from blockchain 13297082
# trying to get block 1from blockchain 13297083
# trying to get block 1from blockchain 13297084
# trying to get block 1from blockchain 13297085
# trying to get block 1from blockchain 13297086
# trying to get block 1from blockchain 13297087
# trying to get block 1from blockchain 13297088
# trying to get block 1from blockchain 13297089
# trying to get block 1from blockchain 13297090
# trying to get block 1from blockchain 13297091
# trying to get block 1from blockchain 13297092
# trying to get block 1from blockchain 13297093
# trying to get block 1from blockchain 13297094
# trying to get block 1from blockchain 13297095
# trying to get block 1from blockchain 13297096
# trying to get block 1from blockchain 13297097
# trying to get block 1from blockchain 13297098
# trying to get block 1from blockchain 13297099
# trying to get block 1from blockchain 13297100
# trying to get block 1from blockchain 13297101
# trying to get block 1from blockchain 13297102
# trying to get block 1from blockchain 13297103
# trying to get block 1from blockchain 13297104
# trying to get block 1from blockchain 13297105
# trying to get block 1from blockchain 13297106
# trying to get block 1from blockchain 13297107
# trying to get block 1from blockchain 13297108
# trying to get block 1from blockchain 13297109
# trying to get block 1from blockchain 13297110
# trying to get block 1from blockchain 13297111
# trying to get block 1from blockchain 13297112
# trying to get block 1from blockchain 13297113
# trying to get block 1from blockchain 13297114
# trying to get block 1from blockchain 13297115
# trying to get block 1from blockchain 13297116
# trying to get block 1from blockchain 13297117
# trying to get block 1from blockchain 13297118
# trying to get block 1from blockchain 13297119
# trying to get block 1from blockchain 13297120
# trying to get block 1from blockchain 13297121
# trying to get block 1from blockchain 13297122
# trying to get block 1from blockchain 13297123
# trying to get block 1from blockchain 13297124
# trying to get block 1from blockchain 13297125
# trying to get block 1from blockchain 13297126
# trying to get block 1from blockchain 13297127
# trying to get block 1from blockchain 13297128
# trying to get block 1from blockchain 13297129
# trying to get block 1from blockchain 13297130
# trying to get block 1from blockchain 13297131
# trying to get block 1from blockchain 13297132
# trying to get block 1from blockchain 13297133
# trying to get block 1from blockchain 13297134
# trying to get block 1from blockchain 13297135
# trying to get block 1from blockchain 13297136
# trying to get block 1from blockchain 13297137
# trying to get block 1from blockchain 13297138
# trying to get block 1from blockchain 13297139
# trying to get block 1from blockchain 13297140
# trying to get block 1from blockchain 13297141
# trying to get block 1from blockchain 13297142
# trying to get block 1from blockchain 13297143
# trying to get block 1from blockchain 13297144
# trying to get block 1from blockchain 13297145
# trying to get block 1from blockchain 13297146
# trying to get block 1from blockchain 13297147
# trying to get block 1from blockchain 13297148
# trying to get block 1from blockchain 13297149
# trying to get block 1from blockchain 13297150
# trying to get block 1from blockchain 13297151
# trying to get block 1from blockchain 13297152
# trying to get block 1from blockchain 13297153
# trying to get block 1from blockchain 13297154
# trying to get block 1from blockchain 13297155
# trying to get block 1from blockchain 13297156
# trying to get block 1from blockchain 13297157
# trying to get block 1from blockchain 13297158
# trying to get block 1from blockchain 13297159
# trying to get block 1from blockchain 13297160
# trying to get block 1from blockchain 13297161
# trying to get block 1from blockchain 13297162
# trying to get block 1from blockchain 13297163
# trying to get block 1from blockchain 13297164
# trying to get block 1from blockchain 13297165
# trying to get block 1from blockchain 13297166
# trying to get block 1from blockchain 13297167
# trying to get block 1from blockchain 13297168
# trying to get block 1from blockchain 13297169
# trying to get block 1from blockchain 13297170
# trying to get block 1from blockchain 13297171
# trying to get block 1from blockchain 13297172
# trying to get block 1from blockchain 13297173
# trying to get block 1from blockchain 13297174
# trying to get block 1from blockchain 13297175

# %%
import pandas as pd
import requests

def Moralis(limit=10, block_start=13296577, blocks=1, lines_to_save_data_per_block=50000, data_folder='', chain='eth'):
    my_headers = {'X-API-Key' : 'wxnVT0JB4Ic27JWoP7nFOP2Ims6fLdyrEMPCZ9TbKvrQOnIv8Loq1Qz7UPayuTGE'}

    for block in range(blocks):
        df = pd.DataFrame({}, dtype=str)
        offset = 0
        block_on_chain=block_start + block
        url = 'https://deep-index.moralis.io/api/v2/block/'+str(block_on_chain)+'/nft/transfers'
        counter = 0

        while lines_to_save_data_per_block > offset:
            counter += 1
            query= {'chain':chain, 'limit':limit, 'offset': offset}
            try:
                print('trying to get block '+ str(counter) + 'from blockchain ' + str(block_on_chain))
                response = requests.get(url=url, headers=my_headers, params=query)

            except requests.exceptions.HTTPError as error:
                print(error)
                break

            response = response.json()

            df_supp = pd.DataFrame(response['result'], dtype=str)
            if len(df_supp)==0: break
            df = df.append(df_supp, ignore_index=True)

            if response['page_size'] == limit : offset += limit
            else : break
        df.to_csv(data_folder+'moralis'+str(block_on_chain)+'.csv', index=False)

# %%
Moralis(blocks=100,limit=1000)
# Out:
# trying to get block 1from blockchain 13296577
# trying to get block 2from blockchain 13296577
# trying to get block 3from blockchain 13296577
# trying to get block 4from blockchain 13296577
# trying to get block 5from blockchain 13296577
# trying to get block 6from blockchain 13296577
# trying to get block 7from blockchain 13296577
# trying to get block 8from blockchain 13296577
# trying to get block 9from blockchain 13296577
# trying to get block 10from blockchain 13296577
# trying to get block 11from blockchain 13296577
# trying to get block 12from blockchain 13296577
# trying to get block 13from blockchain 13296577
# trying to get block 14from blockchain 13296577
# trying to get block 15from blockchain 13296577
# trying to get block 16from blockchain 13296577
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-231671fafe22> in <module>
# ----> 1 Moralis(blocks=100,limit=1000)
#
# <ipython-input-3-420949c69aff> in Moralis(limit, block_start, blocks, lines_to_save_data_per_block, data_folder, chain)
#      18             try:
#      19                 print('trying to get block '+ str(counter) + 'from blockchain ' + str(block_on_chain))
# ---> 20                 response = requests.get(url=url, headers=my_headers, params=query)
#      21
#      22             except requests.exceptions.HTTPError as error:
#
# c:\Users\Thoma\.conda\envs\nftProj\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# c:\Users\Thoma\.conda\envs\nftProj\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# c:\Users\Thoma\.conda\envs\nftProj\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     527         }
#     528         send_kwargs.update(settings)
# --> 529         resp = self.send(prep, **send_kwargs)
#     530
#     531         return resp
#
# c:\Users\Thoma\.conda\envs\nftProj\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     643
#     644         # Send the request
# --> 645         r = adapter.send(request, **kwargs)
#     646
#     647         # Total elapsed time of the request (approximately)
#
# c:\Users\Thoma\.conda\envs\nftProj\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438         try:
#     439             if not chunked:
# --> 440                 resp = conn.urlopen(
#     441                     method=request.method,
#     442                     url=url,
#
# c:\Users\Thoma\.conda\envs\nftProj\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# c:\Users\Thoma\.conda\envs\nftProj\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# c:\Users\Thoma\.conda\envs\nftProj\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\Users\Thoma\.conda\envs\nftProj\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# c:\Users\Thoma\.conda\envs\nftProj\lib\http\client.py in getresponse(self)
#    1346         try:
#    1347             try:
# -> 1348                 response.begin()
#    1349             except ConnectionError:
#    1350                 self.close()
#
# c:\Users\Thoma\.conda\envs\nftProj\lib\http\client.py in begin(self)
#     314         # read until we get a non-100 response
#     315         while True:
# --> 316             version, status, reason = self._read_status()
#     317             if status != CONTINUE:
#     318                 break
#
# c:\Users\Thoma\.conda\envs\nftProj\lib\http\client.py in _read_status(self)
#     275
#     276     def _read_status(self):
# --> 277         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278         if len(line) > _MAXLINE:
#     279             raise LineTooLong("status line")
#
# c:\Users\Thoma\.conda\envs\nftProj\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# c:\Users\Thoma\.conda\envs\nftProj\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# c:\Users\Thoma\.conda\envs\nftProj\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
for block in range(1):
    print(block)
# Out:
# 0
