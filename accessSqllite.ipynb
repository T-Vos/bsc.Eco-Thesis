# %%
import pandas as pd
import sqlite3


# Create a SQL connection to our SQLite database
con = sqlite3.connect("./DataOtherSources/EthereumNFTs/nfts.sqlite")

cur = con.cursor()
df = pd.read_sql_query("SELECT * from transfers", con)
# print(df.head(10))
# Be sure to close the connection
con.close()

# %%
df.iloc[0:1,4][0]
# Out:
# '66829341423052781770025301071383202464868633560790161876654769815409366730947'

# %%
df.head(1)
# Out:
#                                event_id  \
# 0  cd816651-56b2-4ed9-887c-c83de732428d
#
#                                     transaction_hash  block_number  \
# 0  0x0c73daad5e6946e6b2f1374846d6ba3025d6e6a2569f...      12936373
#
#                                   nft_address  \
# 0  0x629A673A8242c2AC4B7B8C5D8735fbeac21A6205
#
#                                             token_id  \
# 0  6682934142305278177002530107138320246486863356...
#
#                                  from_address  \
# 0  0x25f1d709b329C7349b8209851E90eFa3a7f60178
#
#                                    to_address  transaction_value   timestamp
# 0  0xC69b4c6fFDBaF843A0d0588c99E3C67f27069BEa                0.0  1627776481

# %%
block = 12936373

trades_in_block = df[df["block_number"] == block]
trades_in_block.to_csv('block_12936373.csv')

# %%
blocks = df['block_number'].value_counts()

# %%
block_values = blocks.values

# %%
# df['nft_address'].value_counts(normalize=True).plot(kind="bar")

df_normalized = df['nft_address'].value_counts(normalize=True)

# %%
df_normalized[df_normalized > 0.004].plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df_normalized[df_normalized.index == "0x05295c50e450008A6307c3f6977908b4256c0Da1"]
# Out:
# 0x05295c50e450008A6307c3f6977908b4256c0Da1    0.000003
# Name: nft_address, dtype: float64

# %%
df_normalized["symbol"] = df_normalized["value"].map(lambda x : shortenInt(x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f5f628d468c8> in <module>
# ----> 1 df_normalized["symbol"] = df_normalized["value"].map(lambda x : shortenInt(x))
#
# NameError: name 'df_normalized' is not defined

# %%
import pandas as pd
import sqlite3


# Create a SQL connection to our SQLite database
con = sqlite3.connect("./DataOtherSources/EthereumNFTs/nfts.sqlite")

cur = con.cursor()
nftAddressNames = pd.read_sql_query('SELECT * from nfts', con)
# Be sure to close the connection
con.close()

# %%
nftAddressNames.loc[nftAddressNames['address'] == '0x06012c8cf97BEaD5deAe237070F9587f8E7A266d']
# Out:
#                                       address           name symbol
# 6  0x06012c8cf97BEaD5deAe237070F9587f8E7A266d  CryptoKitties     CK

# %%
nftAddressNames.loc[nftAddressNames['symbol'] == 'KODA']
# Out:
#                                          address                     name  \
# 67    0xFBeef911Dc5821886e1dda71586d90eD28174B7d  KnownOriginDigitalAsset
# 3743  0xABB3738f04Dc2Ec20f4AE4462c3d069d02AE045B  KnownOriginDigitalAsset
#
#      symbol
# 67     KODA
# 3743   KODA

# %%
nftAddressNames.loc[nftAddressNames['symbol'] == 'BAYC']
# Out:
#                                          address                  name symbol
# 554   0xBC4CA0EdA7647A8aB7C2061c2E118A18a936f13D     BoredApeYachtClub   BAYC
# 7474  0x346C71c92Ea6a8D791352e41647135c130060129  Bored Aye Yacht Club   BAYC
# 7486  0x05295c50e450008A6307c3f6977908b4256c0Da1     BoredApeYachtClub   BAYC

# %%
nftAddressNames.loc[nftAddressNames['symbol'] == '']
# Out:
#                                          address  \
# 92    0x62D0bb9aA7e3e49c83E84bc7f94f7028E87DCc5F
# 94    0xc8752D98918de6C0B50E24bC8a18e7165EFB9a3a
# 306   0xBC6c831A566Eb4018b13968c45304Cfc3c674DF8
# 890   0x8436F16c090B0A6B2A7ae4CfCc82E007302a4b38
# 1021  0x646e3163c88A3B4c2ebe10986d2873581dAC3f0f
# 1975  0x9724fDF5aE41570dEcC2D3094C65eafA7E1aB7D4
# 1996  0x8F773b5cc83f42EdF2cc45519DBa27C7F2fAf6FD
# 2120  0xf353231836C4514Ac797479b2Ebf658b004478E2
# 4414  0x7d5773e8FEE4bc9B679c1EB51b2597984c007682
# 4767  0x0cFc1685E94Bc1B47F9770Fc7909e1Df945FBb1D
# 5241  0xF1b328c12bbc1b1f3d593C067Be0d1c28EC9Fe1D
# 5911  0xcEb2EA7E904c74Aaa205eb29581B13b4E16623B2
# 6184  0x5f521863D82b1D52b3126116CfB60fe00E5e2701
# 6645  0xfD62049145D3820E3fc935144Fa80aA1707B53F5
# 6837  0x03d736D07155c48312444e201388db3df80b6B76
# 7174  0x6a76f1c362f2C871BEB9d930c9eFd02B07841A28
# 7175  0xF0b7DE03134857391d8D43Ed48e20EDF21461097
# 7176  0xa08b1215ff7Ad33fa431E35569F95F684Cd9Bf9c
# ...

# %%
BAYC = "0xBC4CA0EdA7647A8aB7C2061c2E118A18a936f13D"

bayc_trades = df[df["nft_address"] == BAYC]
bayc_trades.iloc[10,1]

# %%
SOR = "0x629A673A8242c2AC4B7B8C5D8735fbeac21A6205"

sor_trades = df[df["nft_address"] == SOR]
sor_trades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 377831 entries, 0 to 4514726
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   event_id           377831 non-null  object
#  1   transaction_hash   377831 non-null  object
#  2   block_number       377831 non-null  int64
#  3   nft_address        377831 non-null  object
#  4   token_id           377831 non-null  object
#  5   from_address       377831 non-null  object
#  6   to_address         377831 non-null  object
#  7   transaction_value  377831 non-null  float64
#  8   timestamp          377831 non-null  int64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 28.8+ MB

# %%
sor_trades.head(2)
# Out:
#                                event_id  \
# 0  cd816651-56b2-4ed9-887c-c83de732428d
# 1  82cc5228-eb80-4e0d-9f6f-e644dec3ab06
#
#                                     transaction_hash  block_number  \
# 0  0x0c73daad5e6946e6b2f1374846d6ba3025d6e6a2569f...      12936373
# 1  0x0c73daad5e6946e6b2f1374846d6ba3025d6e6a2569f...      12936373
#
#                                   nft_address  \
# 0  0x629A673A8242c2AC4B7B8C5D8735fbeac21A6205
# 1  0x629A673A8242c2AC4B7B8C5D8735fbeac21A6205
#
#                                             token_id  \
# 0  6682934142305278177002530107138320246486863356...
# 1  1198507443711741845273832738859307575893198744...
#
#                                  from_address  \
# 0  0x25f1d709b329C7349b8209851E90eFa3a7f60178
# 1  0x0737E7162C88E9FBB963334e4Bfe6e97447fF811
#
#                                    to_address  transaction_value   timestamp
# 0  0xC69b4c6fFDBaF843A0d0588c99E3C67f27069BEa                0.0  1627776481
# ...

# %%
sor_trades["date"] = pd.to_datetime(sor_trades.iloc[:, 8],unit='s')
# Out:
# <ipython-input-11-c7af51dc7581>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sor_trades["date"] = pd.to_datetime(sor_trades.iloc[:, 8],unit='s')

# %%
sor_trades.iloc[-2]
# Out:
# event_id                          73c81c59-c17a-4154-8bbc-5d72a27ee905
# transaction_hash     0x883257f2403851cf4f1f19a87728aafe269791fe0fcd...
# block_number                                                  12545211
# nft_address                 0x629A673A8242c2AC4B7B8C5D8735fbeac21A6205
# token_id             2572313837129053907318259388395403352463424684...
# from_address                0x327305A797d92a39cEe1a225D7E2A1cC42B1a8fA
# to_address                  0xDe747F2AF4627c1646C206eC7289597039ba319E
# transaction_value                                                    0
# timestamp                                                   1622505446
# date                                               2021-05-31 23:57:26
# Name: 4514725, dtype: object

# %%
df_normalized = df['nft_address'].value_counts(normalize=True)

# %%
def findSymbol(value):
    return nftAddressNames.loc[nftAddressNames['address'] == value].symbol

# %%
df_normalized.sort_values(ascending=False)
df_normalized.to_csv("norm.csv")
for key in  df_normalized.iloc[0:30].keys() :
    print(findSymbol(key))
# Out:
# 33    SOR
# Name: symbol, dtype: object
# 50    None
# Name: symbol, dtype: object
# 99    BLOCKS
# Name: symbol, dtype: object
# 20    FNDNFT
# Name: symbol, dtype: object
# 6    CK
# Name: symbol, dtype: object
# 554    BAYC
# Name: symbol, dtype: object
# 610    COOL
# Name: symbol, dtype: object
# 621    PPG
# Name: symbol, dtype: object
# 70    LAND
# Name: symbol, dtype: object
# 4062    ACBN
# Name: symbol, dtype: object
# 541    TWC
# Name: symbol, dtype: object
# 3914    ABS
# Name: symbol, dtype: object
# 6023    MICE
# Name: symbol, dtype: object
# 44    RARI
# Name: symbol, dtype: object
# 579    HM
# Name: symbol, dtype: object
# 2783    WKDAPE
# Name: symbol, dtype: object
# 595    ⚇
# Name: symbol, dtype: object
# 772    CAMELS
# Name: symbol, dtype: object
# 5784    DINO
# Name: symbol, dtype: object
# 1956    LION
# Name: symbol, dtype: object
# 616    TABOY
# Name: symbol, dtype: object
# 576    WOW
# Name: symbol, dtype: object
# 571    WMCR
# ...

# %%
nftAddressNames.loc[nftAddressNames['address'] == '0x57f1887a8BF19b14fC0dF6Fd9B2acc9Af147eA85']
# Out:
#                                        address  name symbol
# 50  0x57f1887a8BF19b14fC0dF6Fd9B2acc9Af147eA85  None   None

# %%
df_normalized["0xBC4CA0EdA7647A8aB7C2061c2E118A18a936f13D"]
# Out:
# 0.007744872394334189

# %%
df_normalized.head(10).plot(kind="bar")
# Out:
# <AxesSubplot:>
