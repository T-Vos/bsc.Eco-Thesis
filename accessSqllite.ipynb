# %%
import pandas as pd
import sqlite3


# Create a SQL connection to our SQLite database
con = sqlite3.connect("./DataOtherSources/EthereumNFTs/nfts.sqlite")

cur = con.cursor()
df = pd.read_sql_query("SELECT * from transfers", con)
print(df.head(10))
# Be sure to close the connection
con.close()
# Out:
#                                event_id  \
# 0  cd816651-56b2-4ed9-887c-c83de732428d
# 1  82cc5228-eb80-4e0d-9f6f-e644dec3ab06
# 2  6e1f9cc4-d1df-4a6b-972d-a20765beb326
# 3  43dc27a7-a72d-4894-809c-e868de05f7ee
# 4  47b7839b-9b87-442d-b2c1-9ebedcad8e06
# 5  aa9cfbfe-e787-4e13-9aef-09fb02468a55
# 6  2c6e69bc-29aa-4f46-8c30-b91dc349042e
# 7  7de81ec5-bbf6-485c-b804-3f2de2a63b3d
# 8  e9ce8274-2ddd-4bfb-accf-b1da1c42fa5f
# 9  9cc5c9e4-e570-4b93-9731-6ac6c27b01ce
#
#                                     transaction_hash  block_number  \
# 0  0x0c73daad5e6946e6b2f1374846d6ba3025d6e6a2569f...      12936373
# 1  0x0c73daad5e6946e6b2f1374846d6ba3025d6e6a2569f...      12936373
# 2  0x0c73daad5e6946e6b2f1374846d6ba3025d6e6a2569f...      12936373
# 3  0x0c73daad5e6946e6b2f1374846d6ba3025d6e6a2569f...      12936373
# 4  0x0c73daad5e6946e6b2f1374846d6ba3025d6e6a2569f...      12936373
# 5  0x0c73daad5e6946e6b2f1374846d6ba3025d6e6a2569f...      12936373
# 6  0x0c73daad5e6946e6b2f1374846d6ba3025d6e6a2569f...      12936373
# 7  0xe9c8dbd55c37189b68441c408f820ed9a954f8dd7500...      12936373
# 8  0xf6c06191e0af12dd0632bde871b02e8089e0bca30167...      12936373
# 9  0xefdb2cd352aee3f35684480308dd7aa4cc080f38b60e...      12936373
#
#                                   nft_address  \
# 0  0x629A673A8242c2AC4B7B8C5D8735fbeac21A6205
# 1  0x629A673A8242c2AC4B7B8C5D8735fbeac21A6205
# 2  0x629A673A8242c2AC4B7B8C5D8735fbeac21A6205
# 3  0x629A673A8242c2AC4B7B8C5D8735fbeac21A6205
# 4  0x629A673A8242c2AC4B7B8C5D8735fbeac21A6205
# 5  0x629A673A8242c2AC4B7B8C5D8735fbeac21A6205
# 6  0x629A673A8242c2AC4B7B8C5D8735fbeac21A6205
# 7  0x1A92f7381B9F03921564a437210bB9396471050C
# 8  0xb932a70A57673d89f4acfFBE830E8ed7f75Fb9e0
# 9  0x06012c8cf97BEaD5deAe237070F9587f8E7A266d
#
#                                             token_id  \
# 0  6682934142305278177002530107138320246486863356...
# 1  1198507443711741845273832738859307575893198744...
# 2  1541220344281436903042142177888467401468454835...
# 3  7993840355029527745913866651030234226423689128...
# 4  1123719749142984581497870712442861055686734521...
# 5  1007526653752261191799852569675598586564706892...
# 6  4411263470107636521063941389109292065186578341...
# 7                                               6554
# 8                                               4865
# 9                                            1416156
#
#                                  from_address  \
# 0  0x25f1d709b329C7349b8209851E90eFa3a7f60178
# 1  0x0737E7162C88E9FBB963334e4Bfe6e97447fF811
# 2  0xA0fEc186c4b3FAd39ca373dFdd52E79C2495F2c3
# 3  0x90bE22069560A9bAd99543B4A922d1FE34Ae84E9
# 4  0xA8E9C42Ebb915EeEC5080B7Bcc5D844475595091
# 5  0xDaf6ae49094Fde87d4FD3c6D19195e94FB25a069
# 6  0xA62E90BF944A7f5B57e4C84db343544db4D1d419
# 7  0x1B64D74bB19C9d657d63E04e01D040b6abbF2108
# 8  0x8c9F364bf7a56Ed058fc63Ef81c6Cf09c833e656
# 9  0x7aB6478CDD77acd0bDe4aD9620C1570cB12504E9
#
#                                    to_address  transaction_value   timestamp
# 0  0xC69b4c6fFDBaF843A0d0588c99E3C67f27069BEa                0.0  1627776481
# 1  0xC69b4c6fFDBaF843A0d0588c99E3C67f27069BEa                0.0  1627776481
# 2  0xC69b4c6fFDBaF843A0d0588c99E3C67f27069BEa                0.0  1627776481
# 3  0xC69b4c6fFDBaF843A0d0588c99E3C67f27069BEa                0.0  1627776481
# 4  0xC69b4c6fFDBaF843A0d0588c99E3C67f27069BEa                0.0  1627776481
# 5  0xC69b4c6fFDBaF843A0d0588c99E3C67f27069BEa                0.0  1627776481
# 6  0xC69b4c6fFDBaF843A0d0588c99E3C67f27069BEa                0.0  1627776481
# 7  0x114f1388fAB456c4bA31B1850b244Eedcd024136                0.0  1627776481
# 8  0x900E7aD1ab18CeBb4c21F71795364E9B636831CA                0.0  1627776481
# 9  0xAF0b85097971e4149A294f462868DF07ED41cc70                0.0  1627776481

# %%
df.to_csv('./data/nftTransactions.csv')

# %%
df.iloc[0:1,4][0]
# Out:
# '66829341423052781770025301071383202464868633560790161876654769815409366730947'

# %%
df.head(1)
# Out:
#                                event_id  \
# 0  cd816651-56b2-4ed9-887c-c83de732428d
#
#                                     transaction_hash  block_number  \
# 0  0x0c73daad5e6946e6b2f1374846d6ba3025d6e6a2569f...      12936373
#
#                                   nft_address  \
# 0  0x629A673A8242c2AC4B7B8C5D8735fbeac21A6205
#
#                                             token_id  \
# 0  6682934142305278177002530107138320246486863356...
#
#                                  from_address  \
# 0  0x25f1d709b329C7349b8209851E90eFa3a7f60178
#
#                                    to_address  transaction_value   timestamp
# 0  0xC69b4c6fFDBaF843A0d0588c99E3C67f27069BEa                0.0  1627776481

# %%
# df['nft_address'].value_counts(normalize=True).plot(kind="bar")

df_normalized = df['nft_address'].value_counts(normalize=True)

# %%
df_normalized[df_normalized > 0.004].plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df_normalized.head(1)
# Out:
# 0x629A673A8242c2AC4B7B8C5D8735fbeac21A6205    0.083689
# Name: nft_address, dtype: float64

# %%
import pandas as pd
import sqlite3


# Create a SQL connection to our SQLite database
con = sqlite3.connect("./DataOtherSources/EthereumNFTs/nfts.sqlite")

cur = con.cursor()
mostTradedNFT = pd.read_sql_query('SELECT * from nfts', con)
# Be sure to close the connection
con.close()

# %%
mostTradedNFT.loc[mostTradedNFT['address'] == '0x57f1887a8BF19b14fC0dF6Fd9B2acc9Af147eA85']
# Out:
#                                        address  name symbol
# 50  0x57f1887a8BF19b14fC0dF6Fd9B2acc9Af147eA85  None   None
